# %%
import requests
import json

# %%
user = {'username': 'joshuadrc', 'email': 'jsd42@duke.edu','password': 'Admin10!', 'age': 26, 'activity_level': 2, 'gender_identity': 1}

# %% [markdown]
# ## Registration

# %%
#create user if not already created
r = requests.post('http://127.0.0.1:5000/registration', json = user)
print(r.json())
# Out:
# {'message': 'Username "joshuadrc" is already taken. Please choose another username.'}

# %%
valid_json = {'token':'ImFzZGZmZHlmQHlhaG9vLmNvbSI.Xqb-qw.B1ERticFacwUfM_UA5m_rClPo3U'}

r = requests.post('http://127.0.0.1:5000/verification', json = valid_json)
r.url
# Out:
# 'http://127.0.0.1:5000/verification'

# %%
r.headers
# Out:
# {'Content-Type': 'application/json', 'Content-Length': '70', 'Allow': 'OPTIONS, GET, HEAD', 'Server': 'Werkzeug/1.0.1 Python/3.8.2', 'Date': 'Wed, 29 Apr 2020 18:34:14 GMT'}

# %% [markdown]
# ## Login

# %%
#login user
r = requests.post('http://127.0.0.1:5000/login', json = user)
data = r.json()

try:
    access = data['access_token']
    refresh = data['refresh_token']
    print(data['message'])
    print('JSON Web Token: ' + access[:30])
except:
    print(data['message'])
# Out:
# Logged in as joshuadrc (user)
# JSON Web Token: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUz

# %% [markdown]
# ## Refresh Token

# %%
headers = { 'Authorization' : 'Bearer ' + refresh}

r = requests.post('http://127.0.0.1:5000/token/refresh', headers=headers)
data = r.json()
access = data['access_token']
print(data['message'])
# Out:
# Your access token was generated by using a refresh token.

# %% [markdown]
# ## Admin Check

# %%
headers = { 'Authorization' : 'Bearer ' + access}
payload = {'action': 'get_preferences', 'new_admin':'joshuadrc1'}
r = requests.post('http://127.0.0.1:5000/admin', headers=headers, json=payload)
r.json()
# Out:
# {'message': 'Forbidden, you do not have admin privelages.'}

# %% [markdown]
# ## Edit preferences

# %%
headers = { 'Authorization' : 'Bearer ' + access}

data = {'preference': 'hamburger', 
        'preference_action': 'add'}

r = requests.post('http://127.0.0.1:5000/edit', json = data, headers = headers)
r.json()
# Out:
# {'message': 'hamburger successfully added for joshuadrc.'}

# %% [markdown]
# ## List preferences

# %%
headers = { 'Authorization' : 'Bearer ' + access}
r = requests.get('http://127.0.0.1:5000/prefs', headers = headers)
r.json()['message']
# Out:
# [{'username': 'joshuadrc',
#   'preference': 'peach',
#   'added': '2020-04-29 13:47:57.755746'},
#  {'username': 'joshuadrc',
#   'preference': 'peach',
#   'added': '2020-04-29 13:51:40.282189'},
#  {'username': 'joshuadrc',
#   'preference': 'peach',
#   'added': '2020-04-29 14:32:08.650727'},
#  {'username': 'joshuadrc',
#   'preference': 'peach',
#   'added': '2020-04-29 14:34:15.438609'},
#  {'username': 'joshuadrc',
#   'preference': 'hamburger',
#   'added': '2020-04-29 14:36:44.708013'}]

# %% [markdown]
# ## Get Recommendation

# %%
headers = { 'Authorization' : 'Bearer ' + access}
location = {'latitude': 35.0, 'longitude': -78}

r = requests.post('http://127.0.0.1:5000/recommendation', headers = headers, json=location)

try:
    for i in json.loads(r.json()['data']):
        print('-----------------------------------------------------------')
        print('Based on: ' + user['username'] + '\'s preference for ' + i['previous_item'])
        print('-----------------------------------------------------------')
        for item in i:
            print(f'{item}: {i[item]} \n')
except: 
    print(r.json()['msg'])
# Out:
# -----------------------------------------------------------
# Based on: joshuadrc's preference for peach
# -----------------------------------------------------------
# item_name: Georgia Peach
#
# description:
#
# location: [35.93461, -78.821683]
#
# distance: 6385.597330538458
#
# restaurant: YoFresh Yogurt Cafe
#
# price:
#
# previous_item: peach
#
# ...

# %% [markdown]
# ## Logout

# %%
headers = { 'Authorization' : 'Bearer ' + access}
r = requests.post('http://127.0.0.1:5001/logout/access', headers = headers)
r.json()
# Out:
# {'message': 'Access token has been revoked. You will be unable to use this token in the future.'}

# %%
r = requests.get('http://127.0.0.1:5000/mail')

# %%
r.content
# Out:
# b'null\n'
