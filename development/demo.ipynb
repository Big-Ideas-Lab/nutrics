# %%
import requests
import json

# %%
user = {'username': 'administrator', 'email': 'jsd42@duke.edu','password': 'Admin10!', 'age': 26, 'activity_level': 2, 'gender_identity': 1}

# %% [markdown]
# ## Registration

# %%
#create user if not already created
r = requests.post('http://127.0.0.1:5000/registration', json = user)
print(r.json())
# Out:
# {'message': 'User joshuadrc1 was created. Validation link sent to email.', 'email_sent_to': 'jsd42@duke.edu'}

# %%
valid_json = {'token':'ImFzZGZmZHlmQHlhaG9vLmNvbSI.Xqb-qw.B1ERticFacwUfM_UA5m_rClPo3U'}

r = requests.post('http://127.0.0.1:5000/verification', json = valid_json)
r.url
# Out:
# 'http://127.0.0.1:5000/verification'

# %%
r.headers
# Out:
# {'Content-Type': 'application/json', 'Content-Length': '51', 'Server': 'Werkzeug/1.0.1 Python/3.8.2', 'Date': 'Mon, 27 Apr 2020 15:48:15 GMT'}

# %% [markdown]
# ## Login

# %%
#login user
r = requests.post('http://127.0.0.1:5000/login', json = user)
data = r.json()

try:
    access = data['access_token']
    refresh = data['refresh_token']
    print(data['message'])
    print('JSON Web Token: ' + access[:30])
except:
    print(data['message'])
# Out:
# Logged in as administrator. (admin)
# JSON Web Token: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUz

# %% [markdown]
# ## Refresh Token

# %%
headers = { 'Authorization' : 'Bearer ' + refresh}

r = requests.post('http://127.0.0.1:5000/token/refresh', headers=headers)
data = r.json()
access = data['access_token']
print(data['message'])
# Out:
# Your access token was generated by using a refresh token.

# %% [markdown]
# ## Admin Check

# %%
headers = { 'Authorization' : 'Bearer ' + access}
payload = {'action': 'get_preferences', 'new_admin':'joshuadrc1'}
r = requests.post('http://127.0.0.1:5000/admin', headers=headers, json=payload)
r.json()
# Out:
# {'message': []}

# %% [markdown]
# ## Edit preferences

# %%
headers = { 'Authorization' : 'Bearer ' + access}

data = {'preference': 'peach', 
        'preference_action': 'add'}

r = requests.post('http://127.0.0.1:5000/edit', json = data, headers = headers)
r.json()
# Out:
# {'message': 'peach successfully added for administrator.'}

# %% [markdown]
# ## List preferences

# %%
headers = { 'Authorization' : 'Bearer ' + access}
r = requests.get('http://127.0.0.1:5000/prefs', headers = headers)
r.json()['message']
# Out:
# [{'username': 'administrator',
#   'preference': 'apple',
#   'added': '2020-04-28 12:26:22.640961'},
#  {'username': 'administrator',
#   'preference': 'peach',
#   'added': '2020-04-28 12:26:31.155882'}]

# %% [markdown]
# ## Get Recommendation

# %%
headers = { 'Authorization' : 'Bearer ' + access}
location = {'latitude': 35.0, 'longitude': -78}

r = requests.post('http://127.0.0.1:5000/recommendation', headers = headers, json=location)

try:
    for i in json.loads(r.json()['data']):
        print('-----------------------------------------------------------')
        print('Based on: ' + user['username'] + '\'s preference for ' + i['previous_item'])
        print('-----------------------------------------------------------')
        for item in i:
            print(f'{item}: {i[item]} \n')
except: 
    print(r.json()['msg'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-24f650c8691e> in <module>
#      12             print(f'{item}: {i[item]} \n')
#      13 except:
# ---> 14     print(r.json()['msg'])
#
# ~/miniconda3/envs/nutrics/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/miniconda3/envs/nutrics/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/miniconda3/envs/nutrics/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/miniconda3/envs/nutrics/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Logout

# %%
headers = { 'Authorization' : 'Bearer ' + access}
r = requests.post('http://127.0.0.1:5001/logout/access', headers = headers)
r.json()
# Out:
# {'message': 'Access token has been revoked. You will be unable to use this token in the future.'}

# %%
r = requests.get('http://127.0.0.1:5000/mail')

# %%
r.content
# Out:
# b'null\n'
